# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook_connected"
pio.templates.default = "plotly_dark"

# %% [markdown]
# ## Processing File Names

# %%
future = "option_data/FUTIDX_BANKNIFTY_05-01-2021_TO_04-01-2023 (2).csv"
option = "option_data/OPTIDX_BANKNIFTY_PE_05-01-2021_TO_04-01-2023 (2).csv"
df1 = pd.read_csv(future)
df2 = pd.read_csv(option)

# %%
df1.head()
# Out:
#       Symbol         Date       Expiry      Open      High       Low  \
# 0  BANKNIFTY  29-Jul-2022  27-Oct-2022  37895.95  38000.00  37550.00
# 1  BANKNIFTY  01-Aug-2022  27-Oct-2022  37882.40  38253.00  37746.60
# 2  BANKNIFTY  02-Aug-2022  27-Oct-2022  38053.05  38495.50  37950.25
# 3  BANKNIFTY  03-Aug-2022  27-Oct-2022  38286.85  38396.80  38040.00
# 4  BANKNIFTY  04-Aug-2022  27-Oct-2022  38433.00  38542.15  37623.65
#
#       Close       LTP  Settle Price  No. of contracts  Turnover in Lacs  \
# 0  37826.70  37843.40      37826.70              1227          11600.21
# 1  38217.95  38228.60      38217.95              2225          21185.16
# 2  38322.10  38214.05      38322.10              2121          20276.29
# 3  38313.40  38337.25      38313.40              1623          15498.04
# 4  38063.50  38040.00      38063.50              2736          26031.63
#
#    Open Int  Change in OI Underlying Value
# 0     14475         14475                 -
# 1     27000         12525                 -
# 2     31325          4325                 -
# 3     33425          2100          37989.25
# 4     43900         10475          37755.55

# %% [markdown]
# File Name Structure:
#
# `{Symbol}_{Type}_{Expiry}_{Strike}_{CE/PE}`

# %% [markdown]
# Columns to Keep:
# 1. Date
# 2. Open
# 3. High
# 4. Low
# 5. Close
# 6. Underlying Value

# %%
def preprocess_files(file_dir):
    parent_dir = os.path.split(file_dir)[0]
    df = pd.read_csv(file_dir)
    is_options = False
    symbol = df["Symbol"][0]
    expiry = df["Expiry"][0]

    if "Option Type" in df.columns:
        is_options = True
        cepe = df["Option Type"][0]
        strike = df["Strike Price"][0]
        underelying = 'Underlying Value'
    else:
        underelying = 'Underlying Value '

    df = df[["Date", "Open", "High", "Low", "Close",  underelying]]
    df.columns = ["Date", "Open", "High", "Low", "Close",  'Underlying Value']
    # df['Underlying Value'].str.replace("-", np.nan)
    if is_options:
        name = f"{symbol}_Options_{expiry}_{strike}_{cepe}.csv"
    else:
        name = f"{symbol}_Futures_{expiry}.csv"
    
    final_name = os.path.join(parent_dir, name)
    df.to_csv(final_name, index=False)
    os.remove(file_dir)

# %%
futs = glob.glob("option_data/FUT*.csv")
opts = glob.glob("option_data/OPT*.csv")
all = futs + opts

for file in all:
    preprocess_files(file)

# %%
def create_option_name(symbol, expiry, strike, cepe):
    return f"{symbol}_Options_{expiry}_{strike}_{cepe}.csv"

def create_future_name(symbol, expiry):
    return f"{symbol}_Futures_{expiry}.csv"


def create_name(symbol, expiry, strike=None, cepe=None, dir="option_data"):
    if strike is None:
        return os.path.join(dir, create_future_name(symbol, expiry))
    else:
        return os.path.join(dir, create_option_name(symbol, expiry, strike, cepe))

# %% [markdown]
# ## Processing Dataframes

# %%
nifty = pd.read_csv("option_data/NIFTY.csv", parse_dates=["Date"], index_col="Date")

# %%
nifty
# Out:
#                 Open      High       Low     Close
# Date
# 2023-01-05  18101.95  18120.30  17892.60  17992.15
# 2023-01-04  18230.65  18243.00  18020.60  18042.95
# 2023-01-03  18163.20  18251.95  18149.80  18232.55
# 2023-01-02  18131.70  18215.15  18086.50  18197.45
# 2022-12-30  18259.10  18265.25  18080.30  18105.30
# ...              ...       ...       ...       ...
# 1995-11-14    916.66    916.66    897.52    902.56
# 1995-11-13    949.29    949.29    916.48    917.26
# 1995-11-10    951.93    951.93    946.00    948.82
# 1995-11-09    960.32    960.32    952.13    953.07
# 1995-11-08    976.28    976.28    962.98    964.01
#
# [6761 rows x 4 columns]

# %%
symbol = "NIFTY"
expiry = "29-Dec-2022"
strike = 18000
cepe = "CE"

nifty_option = pd.read_csv(create_name(symbol, expiry, strike, cepe), parse_dates=["Date"], index_col="Date")

# %%
def preprocess_df(df):
    #setting the underlying value
    df["Underlying Value"] = nifty.loc[df.index, "Close"].values
    df["Underlying Value"] = df["Underlying Value"].fillna(method="ffill")

    #removing the rows with zero open and high
    df = df[(df["Open"] != 0) & (df["High"] != 0)]
    return df

# %%
all_csv = glob.glob("data/*.csv")
all_csv = [x for x in all_csv if "NIFTY.csv" not in x]

# %%
for file in all_csv:
    df = pd.read_csv(file, parse_dates=["Date"], index_col="Date")
    df = preprocess_df(df)
    new_file = file.replace("option_data", "option_data/final")
    df.to_csv(new_file)
    os.remove(file)

# %% [markdown]
# ## Some Plots

# %%
symbol = "NIFTY"
expiry = "29-Dec-2022"
strike = 18000
cepe = "CE"

nifty_option = pd.read_csv(create_name(symbol, expiry, strike, cepe, dir="option_data/final"), parse_dates=["Date"], index_col="Date")

# %%
fig = go.Figure(data=[go.Candlestick(x=nifty_option.index,
                open=nifty_option['Open'],
                high=nifty_option['High'],
                low=nifty_option['Low'],
                close=nifty_option['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3ce90f62-1bfc-4b20-ac2f-45a4e6e4e183" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ce90f62-1bfc-4b20-ac2f-45a4e6e4e183")) {                    Plotly.newPlot(                        "3ce90f62-1bfc-4b20-ac2f-45a4e6e4e183",                        [{"close":[962.4,867.9,879.3,747.4,741.0,500.9,495.0,480.0,420.0,422.4,590.0,530.0,598.75,685.3,682.75,650.0,605.0,580.0,650.0,830.0,910.0,940.0,980.0,1000.0,1080.0,1065.0,1016.75,1030.0,1057.75,1020.0,1050.0,1150.0,1123.85,1084.35,1143.1,1162.0,1350.05,1401.85,1510.0,1459.7,1369.05,1370.0,1280.0,1343.1,1435.3,1350.1,1456.75,1552.85,1640.0,1770.0,1930.25,2050.0,1850.0,1827.85,1760.0,1785.0,1860.0,1711.1,1621.5,1630.05,1615.0,1606.0,1599.5,1760.35,1726.75,1676.75,1637.5,1773.55,1772.35,1671.75,1632.5,1519.55,1381.45,1320.05,1273.5,1307.8,1095.4,1089.3,1060.0,1101.0,1235.25,1142.85,1035.0,1152.65,1264.6,1273.25,1243.45,1200.0,1168.65,1142.4,1153.6,1047.8,917.15,980.9,1064.8,1113.55,1070.2,1079.9,1127.5,1112.3,1096.55,1158.9,1292.25,1355.1,1433.0,1368.9,1380.0,1478.25,1494
# %%
#Plot close price of the option along with the underlying value
# Use different axes for the two plots
fig = go.Figure()
fig.add_trace(go.Scatter(x=nifty_option.index, y=nifty_option["Close"], name="Option Close Price"))
fig.add_trace(go.Scatter(x=nifty_option.index, y=nifty_option["Underlying Value"], name="Underlying Value", yaxis="y2"))
fig.update_layout(
    title="Option Close Price vs Underlying Value",
    xaxis_title="Date",
    yaxis_title="Option Close Price",
    yaxis2=dict(
        title="Underlying Value",
        titlefont=dict(
            color="rgb(148, 103, 189)"
        ),
        tickfont=dict(
            color="rgb(148, 103, 189)"
        ),
        overlaying="y",
        side="right"
    )
)

fig.show()
# Out:
# <div>                            <div id="f73835ed-c8c6-4646-8b0f-7eb23972b2f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f73835ed-c8c6-4646-8b0f-7eb23972b2f4")) {                    Plotly.newPlot(                        "f73835ed-c8c6-4646-8b0f-7eb23972b2f4",                        [{"name":"Option Close Price","x":["2021-04-12T00:00:00","2021-04-15T00:00:00","2021-04-19T00:00:00","2021-05-03T00:00:00","2021-07-02T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-27T00:00:00","2021-08-05T00:00:00","2021-08-11T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-15T00:00:00","2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-26T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","20 ...

# %%
symbol = "NIFTY"
expiry = "29-Dec-2022"

nifty_future = pd.read_csv(create_name(symbol, expiry, dir="option_data/final"), parse_dates=["Date"], index_col="Date")

# %%
fig = go.Figure(data=[go.Candlestick(x=nifty_future.index,
                open=nifty_future['Open'],
                high=nifty_future['High'],
                low=nifty_future['Low'],
                close=nifty_future['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()
# Out:
# <div>                            <div id="586040bf-b7fe-4b96-bdf6-116c780e9dd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("586040bf-b7fe-4b96-bdf6-116c780e9dd7")) {                    Plotly.newPlot(                        "586040bf-b7fe-4b96-bdf6-116c780e9dd7",                        [{"close":[17212.3,17002.4,17393.45,17430.2,17432.25,17328.25,17087.75,17217.4,17110.6,17293.75,17394.25,17588.3,17587.65,17637.05,17656.05,17748.45,17848.0,17893.1,18109.95,18274.45,18186.2,18270.05,18347.45,18299.95,18182.35,18514.45,18468.55,18554.3,18539.55,18470.65,18442.9,18284.05,18373.85,18396.85,18626.15,18646.1,18694.1,18733.6,18874.5,18948.3,18812.55,18817.75,18771.35,18670.25,18720.15,18583.65,18605.2,18703.85,18748.9,18467.0,18328.65,18499.3,18423.95,18275.9,18170.35,17863.9,18027.3,18138.0,18122.35,18182.05],"high":[17307.85,17212.6,17403.95,17539.95,17451.1,17377.7,17336.2,17232.0,17183.85,17455.3,17410.0,17620.0,17680.85,17651.95,17750.0,17869.75,17915.9,17941.0,18120.45,18287.8,18219.95,18297.0,18378.0,18451.6,18245.4,18600.0,18561.4,18580.0,18578.0,18559.7,18510.0,18385.1,18388.85,18451.0,18659.5,18668.2,18742.3,18797.65,18905.05,18998.85,18948.95,18856.4,18790.0,18774.65